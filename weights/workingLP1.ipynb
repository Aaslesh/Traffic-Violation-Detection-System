# %%
# !nvidia-smi
# Out:
# Fri Oct 25 12:57:10 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.80                 Driver Version: 546.80       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4070 ...  WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   52C    P8               4W / 108W |   1340MiB /  8188MiB |      2%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.21  Python-3.12.7 torch-2.5.0+cpu CPU (AMD Ryzen 9 8945H w/ Radeon 780M Graphics)
# Setup complete  (16 CPUs, 15.3 GB RAM, 144.2/401.3 GB disk)

# %%
# !pip install ultralytics
from ultralytics import YOLO 
import os 
from IPython.display import display, Image 
from IPython import display 
display.clear_output()

# %%
# Run inference on an image with YOLO11n
# !yolo predict model=yolo11n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Ultralytics 8.3.21 ðŸš€ Python-3.12.7 torch-2.5.0+cpu CPU (AMD Ryzen 9 8945H w/ Radeon 780M Graphics)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# ...
# image 1/1 C:\Users\Aaslesh\Desktop\mini1\zidane.jpg: 384x640 2 persons, 1 tie, 41.0ms
# Speed: 2.5ms preprocess, 41.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict2
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict
#   0%|          | 0.00/49.2k [00:00<?, ?B/s]
# 100%|##########| 49.2k/49.2k [00:00<00:00, 1.66MB/s]

# %%
# !yolo task=detect mode=train model=yolo11n.pt data="C:\Users\Aaslesh\Desktop\mini1\License Plate Recognition.v6i.yolov11\data.yaml" epochs=10
# Out:
# New https://pypi.org/project/ultralytics/8.3.22 available ðŸ˜ƒ Update with 'pip install -U ultralytics'
# Ultralytics 8.3.21 ðŸš€ Python-3.12.7 torch-2.5.0+cpu CPU (AMD Ryzen 9 8945H w/ Radeon 780M Graphics)
# ...

# %%
# Run inference on an image with YOLO11n
# !yolo predict model=best.pt source="C:\Users\Aaslesh\Desktop\mini1\2.jpg"
# Out:
# Ultralytics 8.3.21 ðŸš€ Python-3.12.7 torch-2.5.0+cpu CPU (AMD Ryzen 9 8945H w/ Radeon 780M Graphics)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 C:\Users\Aaslesh\Desktop\mini1\2.jpg: 640x448 (no detections), 92.0ms
# Speed: 0.0ms preprocess, 92.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs\detect\predict9
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=train model=yolo11n.pt data="A:\study\PROJECTS\MINI\datasets\Helmet\data.yaml" epochs=10
# Out:
# New https://pypi.org/project/ultralytics/8.3.22 available ðŸ˜ƒ Update with 'pip install -U ultralytics'
# Ultralytics 8.3.21 ðŸš€ Python-3.12.7 torch-2.5.0+cpu CPU (AMD Ryzen 9 8945H w/ Radeon 780M Graphics)
# ...

# %%
# Run inference on an image with YOLO11n
# !yolo predict model=besthel.pt source="A:\study\PROJECTS\MINI\datasets\Helmet\valid\images\E0A3798-web_11ac997d-307a-454c-be74-20de93d389e8_grande_jpg.rf.cf5f4a1267522d7c55438ca48b139fa8.jpg"
# Out:
# Ultralytics 8.3.21 ðŸš€ Python-3.12.7 torch-2.5.0+cpu CPU (AMD Ryzen 9 8945H w/ Radeon 780M Graphics)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 A:\study\PROJECTS\MINI\datasets\Helmet\valid\images\E0A3798-web_11ac997d-307a-454c-be74-20de93d389e8_grande_jpg.rf.cf5f4a1267522d7c55438ca48b139fa8.jpg: 640x640 1 0, 46.8ms
# Speed: 2.4ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict10
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=train model=yolo11n.pt data="A:\study\PROJECTS\MINI\datasets\phone\data.yaml" epochs=10
# Out:
# New https://pypi.org/project/ultralytics/8.3.22 available ðŸ˜ƒ Update with 'pip install -U ultralytics'
# Ultralytics 8.3.21 ðŸš€ Python-3.12.7 torch-2.5.0+cpu CPU (AMD Ryzen 9 8945H w/ Radeon 780M Graphics)
# ...

# %%
# Run inference on an image with YOLO11n
# !yolo predict model=bestphn.pt source="A:\study\PROJECTS\MINI\datasets\phone\valid\images\img_10247_jpg.rf.f9a953c91e382f2045bb339f9af2e442.jpg"
# Out:
# Ultralytics 8.3.21 ðŸš€ Python-3.12.7 torch-2.5.0+cpu CPU (AMD Ryzen 9 8945H w/ Radeon 780M Graphics)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 A:\study\PROJECTS\MINI\datasets\phone\valid\images\img_10247_jpg.rf.f9a953c91e382f2045bb339f9af2e442.jpg: 480x640 (no detections), 40.8ms
# Speed: 0.0ms preprocess, 40.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict16
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=train model=yolo11n.pt data="A:\study\PROJECTS\MINI\datasets\seatbelt\Seatbelt.v2i.yolov9\data.yaml" epochs=10
# Out:
# New https://pypi.org/project/ultralytics/8.3.22 available ðŸ˜ƒ Update with 'pip install -U ultralytics'
# train: Scanning A:\study\PROJECTS\MINI\datasets\seatbelt\Seatbelt.v2i.yolov9\train\labels.cache... 1592 images, 1 backgrounds, 0 corrupt: 100%|##########| 1592/1592 [00:00<?, ?it/s]
# train: Scanning A:\study\PROJECTS\MINI\datasets\seatbelt\Seatbelt.v2i.yolov9\train\labels.cache... 1592 images, 1 backgrounds, 0 corrupt: 100%|##########| 1592/1592 [00:00<?, ?it/s]
#
# val: Scanning A:\study\PROJECTS\MINI\datasets\seatbelt\Seatbelt.v2i.yolov9\valid\labels.cache... 455 images, 0 backgrounds, 0 corrupt: 100%|##########| 455/455 [00:00<?, ?it/s]
# val: Scanning A:\study\PROJECTS\MINI\datasets\seatbelt\Seatbelt.v2i.yolov9\valid\labels.cache... 455 images, 0 backgrounds, 0 corrupt: 100%|##########| 455/455 [00:00<?, ?it/s]
#
#   0%|          | 0/100 [00:00<?, ?it/s]
#        1/10         0G      2.301      3.999      2.769         21        640:   0%|          | 0/100 [00:02<?, ?it/s]
# ...

# %%
# Run inference on an image with YOLO11n
# !yolo predict model=bestsbelt.pt source="A:\study\PROJECTS\MINI\datasets\seatbelt\Seatbelt.v2i.yolov9\train\images\1_16a0842572d-2002327_2755823925_16a0842572d_large_jpg.rf.142099c79fbb16a14c668ecb060f0991.jpg"
# Out:
# Ultralytics 8.3.21 ðŸš€ Python-3.12.7 torch-2.5.0+cpu CPU (AMD Ryzen 9 8945H w/ Radeon 780M Graphics)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 A:\study\PROJECTS\MINI\datasets\seatbelt\Seatbelt.v2i.yolov9\train\images\1_16a0842572d-2002327_2755823925_16a0842572d_large_jpg.rf.142099c79fbb16a14c668ecb060f0991.jpg: 640x640 4 0s, 51.4ms
# Speed: 0.0ms preprocess, 51.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict11
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=train model=yolo11n.pt data="A:\study\PROJECTS\MINI\datasets\thriple riding\Traffic Violation Detection.v1i.yolov8\data.yaml" epochs=10
# Out:
# New https://pypi.org/project/ultralytics/8.3.23 available ðŸ˜ƒ Update with 'pip install -U ultralytics'
# Ultralytics 8.3.21 ðŸš€ Python-3.12.7 torch-2.5.0+cpu CPU (AMD Ryzen 9 8945H w/ Radeon 780M Graphics)
# ...

# %%
# Run inference on an image with YOLO11n
# !yolo predict model=best3ride.pt source="A:\study\PROJECTS\MINI\datasets\thriple riding\Traffic Violation Detection.v1i.yolov8\train\images\R-1-_jpg.rf.bc217727205e3faab727c9e80218b29e.jpg"
# Out:
# Ultralytics 8.3.21 ðŸš€ Python-3.12.7 torch-2.5.0+cpu CPU (AMD Ryzen 9 8945H w/ Radeon 780M Graphics)
# YOLO11n summary (fused): 238 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 A:\study\PROJECTS\MINI\datasets\thriple riding\Traffic Violation Detection.v1i.yolov8\train\images\R-1-_jpg.rf.bc217727205e3faab727c9e80218b29e.jpg: 640x640 2 safes, 44.0ms
# Speed: 7.2ms preprocess, 44.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict14
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=train model=yolo11n.pt data="A:\study\PROJECTS\MINI\datasets\hel1\data.yaml" epochs=10
# Out:
# New https://pypi.org/project/ultralytics/8.3.27 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.23 🚀 Python-3.12.7 torch-2.5.0+cpu CPU (AMD Ryzen 9 8945H w/ Radeon 780M Graphics)
# ...

# %%
# Out:
# Ultralytics 8.3.23 🚀 Python-3.12.7 torch-2.5.0+cpu CPU (AMD Ryzen 9 8945H w/ Radeon 780M Graphics)
# train: Scanning A:\study\PROJECTS\MINI\datasets\cell-phone1\train\labels...:   0%|          | 0/3241 [00:00<?, ?it/s]
# train: Scanning A:\study\PROJECTS\MINI\datasets\cell-phone1\train\labels... 90 images, 0 backgrounds, 0 corrupt:   3%|▎         | 90/3241 [00:00<00:03, 862.82it/s]
# train: Scanning A:\study\PROJECTS\MINI\datasets\cell-phone1\train\labels... 194 images, 0 backgrounds, 0 corrupt:   6%|▌         | 194/3241 [00:00<00:03, 955.20it/s]
# train: Scanning A:\study\PROJECTS\MINI\datasets\cell-phone1\train\labels... 306 images, 3 backgrounds, 0 corrupt:   9%|▉         | 306/3241 [00:00<00:02, 1015.10it/s]
# train: Scanning A:\study\PROJECTS\MINI\datasets\cell-phone1\train\labels... 418 images, 3 backgrounds, 0 corrupt:  13%|█▎        | 418/3241 [00:00<00:02, 1051.40it/s]
# ...

# %%
# !yolo task=detect mode=train model=yolo11n.pt data="A:\study\PROJECTS\MINI\datasets\cell-phone1\data.yaml" epochs=10
